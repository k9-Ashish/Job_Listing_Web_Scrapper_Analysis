# %% [markdown]
# <a href="https://colab.research.google.com/github/k9-Ashish/Job_Listing_Web_Scrapper_Analysis/blob/main/Job_Listing_Web_Scrapper_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Statement:
#
#  Navigating the Data Science Job Landscape
# 🚀 Unleash your creativity in crafting a solution that taps into the heartbeat of the data science job market! Envision an ingenious project that seamlessly wields cutting-edge web scraping techniques and illuminating data analysis.
#
# 🔍 Your mission? To engineer a tool that effortlessly gathers job listings from a multitude of online sources, extracting pivotal nuggets such as job descriptions, qualifications, locations, and salaries.
#
# 🧩 However, the true puzzle lies in deciphering this trove of data. Can your solution discern patterns that spotlight the most coveted skills? Are there threads connecting job types to compensation packages? How might it predict shifts in industry demand?
#
# 🎯 The core objectives of this challenge are as follows:
#
# Web Scraping Mastery: Forge an adaptable and potent web scraping mechanism. Your creation should adeptly harvest data science job postings from a diverse array of online platforms. Be ready to navigate evolving website structures and process hefty data loads.
#
# Data Symphony: Skillfully distill vital insights from the harvested job listings. Extract and cleanse critical information like job titles, company names, descriptions, qualifications, salaries, locations, and deadlines. Think data refinement and organization.
#
# Market Wizardry: Conjure up analytical tools that conjure meaningful revelations from the gathered data. Dive into the abyss of job demand trends, geographic distribution, salary variations tied to experience and location, favored qualifications, and emerging skill demands.
#
# Visual Magic: Weave a tapestry of visualization magic. Design captivating charts, graphs, and visual representations that paint a crystal-clear picture of the analyzed data. Make these visuals the compass that guides users through job market intricacies.
#
# 🌐 While the web scraping universe is yours to explore, consider these platforms as potential stomping grounds:
#
# LinkedIn Jobs
#
# Indeed
#
# Naukri
#
# Glassdoor
#
# AngelList
#
# 🎈 Your solution should not only decode the data science job realm but also empower professionals, job seekers, and recruiters to harness the dynamic shifts of the industry. The path is open, the challenge beckons – are you ready to embark on this exciting journey?

# %% [markdown]
# # **Github Link:**

# %% [markdown]
# # **Import Libraries**

# %%
# Let's now import all the required libraries.
import selenium
import pandas as pd
from selenium import webdriver

# %%
# let's first connect to the web driver
driver = webdriver.Chrome(r"C:\Users\Ashish\Downloads\chromedriver_win32\chromedriver.exe")

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in
# “Bangalore” location. You have to scrape the job-title, job-location, company_name,
# experience_required. You have to scrape first 10 jobs data

# %%
url = "https://www.naukri.com"
driver.get(url)

# %%
# finding element for job search bar
search_job = driver.find_element_by_xpath("//input[@class='sugInp']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="8e07a531-9164-4a45-a7f2-8b67ad5b01fb")>

# %%
# write on search bar
search_job.send_keys('Data Analyst')

# %%
# finding element for job location bar
search_loc=driver.find_element_by_id('qsb-location-sugg')
search_loc.send_keys("Bangalore")

# %%
search_btn= driver .find_element_by_xpath("//button[@class='btn']")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="05243454-1895-4054-8de1-33deddd15182")>

# %%
# clicking  using xpath function
search_btn=driver.find_element_by_xpath("//button[@class='btn']")
search_btn.click()

# %%
#so let's extract all the tags having the job titles
title_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="48cbdbaa-13ff-4507-9849-98e7d166106b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="3a678c9e-5d8d-4b33-b1c2-8fa1e7d951b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="30f2bec4-f50b-4b6e-b96c-a11008a3c3ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="a74843c4-6e6f-4056-97ff-7086eafccb50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="dbd0125c-f3a1-4c91-bb93-ffd5baeb0e13")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="8a8358b6-cb01-4054-a934-1bafa4d82d8d")>,
# ...

# %%
# extract the text of the job title  from the tags
job_titles=[]
for i in title_tags:
    if i.text is None:
        job_titles.append('Not')
    else:
        job_titles.append(i.text)
job_titles[:10]
# Out:
# ['Data Scientist / Data Analyst -Business Analyst',
#  'Senior Data Analyst - Data Lineage',
#  'Data analysts',
#  'Data Analyst - Informatica MDM',
#  'Excel VBA Jobs Bangalore | VBA data analyst Jobs',
#  'Data analysts',
#  'Business Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst - Category Demand Management (Revenue & Growth)']

# %%
# lets extract all the tags having company names
company_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
company_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="a1d8740a-cbf1-4314-b6e7-6896ac900646")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="65e28939-50e4-4ec9-b8fa-5265da3c420e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="8a979aa7-cbf9-4e1b-b9d9-727e59ccd278")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="d25f1168-f469-4681-9f03-8eb86a60a3fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="bafe2bf5-7ce3-40f6-b972-8bcc9e86d2e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="5f34f475-968f-4a65-9ac7-06cff0269fb3")>,
# ...

# %%
# Now we will extract the text from the tags by looping over these tags
companies_names=[]

for i in company_tags:
    companies_names.append(i.text)
companies_names[:10]
# Out:
# ['Inflexion Analytix Private Limited',
#  'Opex Global Services',
#  'IBM India Pvt. Limited',
#  'Shell India Markets Private Limited',
#  'Mind Circus Innovation',
#  'IBM India Pvt. Limited',
#  'dotSolved India Pvt., Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.']

# %%
# so lets extract  all the tags having the experience required data
experience_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience'] //span")
experience_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="2bbe2ee1-19c8-4c4d-852d-51a19926206d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="852ef2ab-3703-4f39-863f-3b5d53210e2d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="8d9c2f03-a5ab-4faa-ae78-4f50b0ce210e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="ebc7043a-5958-45f1-bcc6-2edf4e6b5327")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="3efc2fd4-9b73-4850-9f01-ae9b7d2970e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="a4d754fd-560d-46e7-ad4f-2c82fb55b7f7")>,
# ...

# %%
# no we will extract the text  from these tags only by one by looping over these tags
experience_list=[]
for i in experience_tags:
    experience_list.append(i.text)
experience_list[:10]
# Out:
# ['0-3 Yrs',
#  '5-10 Yrs',
#  '5-6 Yrs',
#  '6-9 Yrs',
#  '0-1 Yrs',
#  '3-5 Yrs',
#  '9-13 Yrs',
#  '3-5 Yrs',
#  '3-8 Yrs',
#  '1-4 Yrs']

# %%
locations_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
locations_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="6c663e32-a5e7-4699-8614-2dff752e0c5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="97b19045-90d7-4fab-a36a-3731c7f3e22d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="6ba97d71-9582-4c1d-b961-1dfedb701f8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="48691cf1-ab76-424d-9e72-2c8aaf319d8e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="cc32dae9-6c3e-42e4-8459-648d22460c71")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8e71b3c3e3f839d9496870de33b48d6", element="eff92e60-989b-4058-8b4f-1f47982ad3d6")>,
# ...

# %%
locations_list=[]
for i in locations_tags:
    locations_list.append(i.text)
locations_list[:10]
# Out:
# ['Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bengaluru/Bangalore',
#  'Bangalore/Bengaluru',
#  'Mysore/Mysuru, Coimbatore, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
#So lets check th length of ech element.
print(len(job_titles[:10])),print(len(companies_names[:10])),print(len(experience_list[:10])),print(len(locations_list[:10]))
# Out:
# 10
# 10
# 10
# 10
# (None, None, None, None)

# %% [markdown]
# # Creating a DataFarme for the Data Analyst jobs

# %%
jobs=pd.DataFrame({})
jobs['title']=job_titles[:10]
jobs['company']=companies_names[:10]
jobs['experience_required']=experience_list[:10]
jobs['location']=locations_list[:10]

# %%
jobs
# Out:
#                                                title  \
# 0    Data Scientist / Data Analyst -Business Analyst
# 1                 Senior Data Analyst - Data Lineage
# 2                                      Data analysts
# 3                     Data Analyst - Informatica MDM
# 4   Excel VBA Jobs Bangalore | VBA data analyst Jobs
# 5                                      Data analysts
# 6                              Business Data Analyst
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9  Data Analyst - Category Demand Management (Rev...
#
#                                company experience_required  \
# 0   Inflexion Analytix Private Limited             0-3 Yrs
# 1                 Opex Global Services            5-10 Yrs
# 2               IBM India Pvt. Limited             5-6 Yrs
# 3  Shell India Markets Private Limited             6-9 Yrs
# 4               Mind Circus Innovation             0-1 Yrs
# ...

# %% [markdown]
# We can see that we have created the datset named jobs.

# %%
driver.close()

# %%
jobs.to_csv("Naukri_Job_Data - Sheet1.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df= pd.read_csv("/content/Naukri_Job_Data - Sheet1.csv")

# %%
df
# Out:
#                                                title  \
# 0    Data Scientist / Data Analyst -Business Analyst
# 1                 Senior Data Analyst - Data Lineage
# 2                                      Data analysts
# 3                     Data Analyst - Informatica MDM
# 4   Excel VBA Jobs Bangalore | VBA data analyst Jobs
# 5                                      Data analysts
# 6                              Business Data Analyst
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9  Data Analyst - Category Demand Management (Rev...
#
#                                company experience_required  \
# 0   Inflexion Analytix Private Limited             0-3 Yrs
# 1                 Opex Global Services            5-10 Yrs
# 2               IBM India Pvt. Limited             5-6 Yrs
# 3  Shell India Markets Private Limited             6-9 Yrs
# 4               Mind Circus Innovation             0-1 Yrs
# ...

# %%
df["title"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["company"].value_counts().plot(kind="barh")
# Out:
# <Axes: >

# %%
# Company with the Most Job Listings (Bar chart)
top_company = df['company'].value_counts().idxmax()
company_counts = df['company'].value_counts()
company_counts.plot(kind='bar', figsize=(10, 6))
plt.title(f'Company with the Most Job Listings: {top_company}')
plt.xlabel('Company')
plt.ylabel('Number of Jobs')
plt.xticks(rotation=90)
plt.show()

# %%
# Company Distribution (Pie chart)
company_counts = df['company'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(company_counts, labels=company_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Job Listings by Company')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Bivariate Analysis: Scatter plot between experience_required and location count
location_counts = df['location'].value_counts()
plt.figure(figsize=(10, 6))
plt.scatter(df['experience_required'], df['location'].apply(lambda x: location_counts[x]), alpha=0.5)
plt.title('Bivariate Analysis: Experience vs. Location Count')
plt.xlabel('Years of Experience')
plt.ylabel('Number of Jobs in Location')
plt.show()

# %%
# Convert experience_required to numeric (taking the lower bound)
df['experience_required'] = df['experience_required'].str.extract('(\d+)').astype(float)

# Calculate the average years of experience required for each location
average_experience_by_location = df.groupby('location')['experience_required'].mean().reset_index()

# Create a bar chart to visualize the average experience required by location
plt.figure(figsize=(8, 4))
plt.bar(average_experience_by_location['location'], average_experience_by_location['experience_required'])
plt.title('Average Experience Required by Location')
plt.xlabel('Location')
plt.ylabel('Average Years of Experience Required')
plt.xticks(rotation=90)
plt.show()

# %%
n = 1

plt.figure(figsize=(20,15))

for column in df.columns:

    plt.subplot(2,2,n)

    n = n+1
    sns.histplot(df[column], bins = 100)

    plt.tight_layout()

# %%
df.at[0, 'title'] = 'Risk Analyst'

# %%
df
# Out:
#                                 title                              company  \
# 0                        Risk Analyst   Inflexion Analytix Private Limited
# 1  Senior Data Analyst - Data Lineage                 Opex Global Services
# 2                       Data analysts               IBM India Pvt. Limited
# 3      Data Analyst - Informatica MDM  Shell India Markets Private Limited
# 4                      Data Scientist               Mind Circus Innovation
# 5                       Data analysts               IBM India Pvt. Limited
# 6               Business Data Analyst           dotSolved India Pvt., Ltd.
# 7                        Data Analyst             Myntra Designs Pvt. Ltd.
# 8                        Data Analyst             Myntra Designs Pvt. Ltd.
# 9                   Financial Analyst             Myntra Designs Pvt. Ltd.
#
#    experience_required                                           location
# ...

# %%
df.at[9, 'title'] = 'Financial Analyst'

# %%
df.at[4, 'title'] = 'Data Scientist'

# %%
sns.pairplot(df)

# %%
df
# Out:
#                                 title                              company  \
# 0                        Risk Analyst   Inflexion Analytix Private Limited
# 1  Senior Data Analyst - Data Lineage                 Opex Global Services
# 2                       Data analysts               IBM India Pvt. Limited
# 3      Data Analyst - Informatica MDM  Shell India Markets Private Limited
# 4                      Data Scientist               Mind Circus Innovation
# 5                       Data analysts               IBM India Pvt. Limited
# 6               Business Data Analyst           dotSolved India Pvt., Ltd.
# 7                        Data Analyst             Myntra Designs Pvt. Ltd.
# 8                        Data Analyst             Myntra Designs Pvt. Ltd.
# 9                   Financial Analyst             Myntra Designs Pvt. Ltd.
#
#    experience_required                                           location
# ...

# %%
# Box Plot for Experience Distribution by Location
plt.figure(figsize=(12, 6))
sns.boxplot(x='location', y='experience_required', data=df)
plt.title('Experience Distribution by Location')
plt.xlabel('Location')
plt.ylabel('Years of Experience Required')
plt.xticks(rotation=90)
plt.show()

# %%
# Bar Plot for Company vs. Average Experience
average_experience_by_company = df.groupby('company')['experience_required'].mean().reset_index()
plt.figure(figsize=(12, 6))
plt.bar(average_experience_by_company['company'], average_experience_by_company['experience_required'])
plt.title('Company vs. Average Experience Required')
plt.xlabel('Company')
plt.ylabel('Average Years of Experience Required')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Potential conclusions and insights:**
#
# Experience Distribution: The dataset includes job listings with a wide range of experience requirements, from entry-level positions (0-3 years of experience) to more senior roles (up to 13 years of experience).
#
# Location of Job Opportunities:
#
# The majority of job opportunities are concentrated in major cities like Bangalore/Bengaluru, with some listings in other cities like Mumbai, Hyderabad, Pune, and Gurgaon. This suggests that these cities are significant hubs for data-related roles.Common Job Titles: The most common job titles in the dataset include "Data Analyst," "Senior Data Analyst," and "Business Data Analyst," indicating a demand for professionals with skills in data analysis and business intelligence.Company Insights: Myntra Designs Pvt. Ltd. appears multiple times in the dataset, indicating that it has several job openings. This company might be a significant player in the data analytics job market.Experience vs. Job Count: There seems to be a variety of job opportunities available for candidates with different levels of experience, with a substantial number of entry-level positions as well as more experienced roles.
#
#
# Average Experience by Location:
#
#  The average years of experience required for jobs can vary by location. Some locations might have a higher average experience requirement compared to others, which could reflect regional differences in the job market.Outliers in Experience Requirements: The box plot analysis revealed potential outliers in terms of experience requirements for jobs in different locations. Investigating these outliers further could provide insights into specific industries or companies with unique hiring practices.Company vs.
#
#  Average Experience:
#
#   The bar plot comparing companies to the average years of experience required can help job seekers understand which companies tend to require more or less experience for their data-related roles.
